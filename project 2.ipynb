# %% [markdown]
# # Final Project 2 - Employability Assessment Tool
#
# The dataset **candidates.xlsx** contains the test result of students who gave an online test for job.
#
# **The confidentiality of this dataset has been maintained by changing names, email address and userid of all the students.**
#
# The test consisted of several questions divided in 5 different sections. This dataset has total score as well as section wise scores of each student.
#
# You can download the data from : "link"
#
# ### Dataset description
#
# - Alloted Set - It contains number of set from 1 to 5.
# - Total Score - It contains the total marks scored by the student.
#
# There are 5 different sections and 3 feature columns (given below) for every sections.
#
# - Section **n** - Total questions attempted
# - Wrong Answers **n** - Incorrect attempts
# - Marks **n** - Correct attempts
#
# (n stands for section number)
#
# ### Perform appropriate operations and analytics on the dataset and find the answer of the following questions.
#
# 1. Remove the NaN coloumns. Remove the Rows that contain NaN. Drop all the irrelevnt coloumns.
# 2. Rename the coloumn names to proper ones.
# 3. Capitalize the first letter of the names of students.
# 4. Print the total number of unique sets. Drop any set if it contains extremely less data.
# 5. Print the count and percentage of students in each set.
# 6. Print the set-wise total number and the set-wise percentage of students who have scored more than 40 in total marks.
# 7. Plot a bar graph of Number of Students vs Alotted Set.
# 8. Plot a Histogram for Total Score. There should be 5 histograms for every set.
# 9. Plot a scatter plot for section wise marks vs total marks for each section. Use subplot. Also use different colours for different range of total marks (0-40,40-60,60-100)
# 10. **BONUS QUESTION: Out of the 5 sections, 2 sections have a high correlation. Find those sections and prove by a valid plot/graph/chart/table with a proper reasoing statement. (1 point)**
#
# 11. Print the maximum and minimum marks scored in each section. Which section has got highest maximum marks? Which section has got lowest maximum marks.
# 12. Print the name of toppers for each section. If there are multiple topper students in any section, print the count and names of all of them.
# 13. Plot a stack bar plot of sectionwise scores of the topper.
# 14. Print the names of students in every section who have secured the maximum Correct/Total ratio. If there are multiple topper students in any section, print the count and names of all of them.
# 15. Find out if there is any student who is topper in both above questions (section wise). Such students will be called scholars. Prints the names of all scholars.
# 16. Print the names of students who scored zero.
# 17. Find the count of all students whose Incorrect/Correct Ratio in all sections is more than 1.
# 18. **BONUS QUESTION: For the scholars mentioned above, extract their test result from the original data and convert it in a table of marks format. Write it to a text file. Then write a code to send the mail to all those candidates congratulating them for good performance. (2 points)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('candidates.xlsx')
df
# Out:
#       Sr No.             Username                         Name  \
# 0          1          usmjtsrkrsl             jalkvjgh grkrgtt
# 1          2      cksmrsnsljkhsnv           hfkgyrgn gljkhgnlz
# 2          3            ahjmsnshe          hrHJYGNGHH DKBHGLzg
# 3          4            skhldrrpu            yskuldrrf kuygrgo
# 4          5          zbhhprndrsm        kkbhufrndrg whguhgniy
# 5          6      qpsnkhsrmwsl73v            hpfgnkgj grywglxb
# 6          7             lgsrjmss            kjGgrjyg Ghgryggo
# 7          8            wrsghh76g          nhRGGHH WHGHDHGRYde
# 8          9          jnjtjn8447k              bwnjxjn kuygrov
# 9         10    bsjshwsrysssbslrr         ntGjghwgryg Ggbglrkc
# 10        11       rprjysnksmkrro            vhFrjygnkg Ykrrdl
# 11        12        ksknsljpstjlm             djGknglj fgxjljg
# 12        13      amshjrsvsdrksrv    sxYgyurrgh Ghjrgvgdrkgrju
# 13        14            ykspstjld           srKgrjghyg Fgxjlzj
# ...

# %% [markdown]
# # Q1 Remove the NaN coloumns. Remove the Rows that contain NaN. Drop all the irrelevnt coloumns.

# %%
data=df.dropna()
df.head()
# Out:
#    Sr No.         Username                   Name                    Email  \
# 0       1      usmjtsrkrsl       jalkvjgh grkrgtt      usmjtsrkrsl@xyz.com
# 1       2  cksmrsnsljkhsnv     hfkgyrgn gljkhgnlz  cksmrsnsljkhsnv@xyz.com
# 2       3        ahjmsnshe    hrHJYGNGHH DKBHGLzg        ahjmsnshe@xyz.com
# 3       4        skhldrrpu      yskuldrrf kuygrgo        skhldrrpu@xyz.com
# 4       5      zbhhprndrsm  kkbhufrndrg whguhgniy      zbhhprndrsm@xyz.com
#
#    Alloted Set  Total Score  Section1  Wrong Answers 1  Marks 1  Section2  \
# 0            1           34        25               12       13        25
# 1            1           32        25               16        9        25
# 2            1           34        25               17        8        25
# 3            1           27        19               10        9        15
# 4            1           35        25               13       12        17
#
#    ...  Marks 2  Section3  Wrong Answers 3  Marks 3  Section4  \
# ...

# %%
sr_name =data[["Sr No.",'Name']]
x=sr_name.groupby(['Name'])
x.head()
# Out:
#       Sr No.                         Name
# 0          1             jalkvjgh grkrgtt
# 1          2           hfkgyrgn gljkhgnlz
# 2          3          hrHJYGNGHH DKBHGLzg
# 3          4            yskuldrrf kuygrgo
# 4          5        kkbhufrndrg whguhgniy
# 5          6            hpfgnkgj grywglxb
# 6          7            kjGgrjyg Ghgryggo
# 7          8          nhRGGHH WHGHDHGRYde
# 8          9              bwnjxjn kuygrov
# 9         10         ntGjghwgryg Ggbglrkc
# 10        11            vhFrjygnkg Ykrrdl
# 11        12             djGknglj fgxjljg
# 12        13    sxYgyurrgh Ghjrgvgdrkgrju
# 13        14           srKgrjghyg Fgxjlzj
# 14        15        fnGhubhgngj Kuybhgrpb
# 15        16           syGhruxjkg Fgxjlqg
# 16        17             iiXgnygy Jkghjnd
# 17        18           jiNGYRGXG FHJGRJtd
# 18        19            emGnkjxg Hujgrrht
# 19        20              yvGnujg Fgxjlli
# 20        21          gkFrgjgkxg ghjndrnc
# ...

# %% [markdown]
# #  Q3 Capitalize the first letter of the names of students.

# %%
df["Name"].apply(lambda data: data.capitalize())
# Out:
# 0                  Jalkvjgh grkrgtt
# 1                Hfkgyrgn gljkhgnlz
# 2               Hrhjygnghh dkbhglzg
# 3                 Yskuldrrf kuygrgo
# 4             Kkbhufrndrg whguhgniy
# 5                 Hpfgnkgj grywglxb
# 6                 Kjggrjyg ghgryggo
# 7               Nhrgghh whghdhgryde
# 8                   Bwnjxjn kuygrov
# 9              Ntgjghwgryg ggbglrkc
# 10                Vhfrjygnkg ykrrdl
# 11                 Djgknglj fgxjljg
# 12        Sxygyurrgh ghjrgvgdrkgrju
# 13               Srkgrjghyg fgxjlzj
# 14            Fnghubhgngj kuybhgrpb
# 15               Syghruxjkg fgxjlqg
# 16                 Iixgnygy jkghjnd
# 17               Jingyrgxg fhjgrjtd
# 18                Emgnkjxg hujgrrht
# 19                  Yvgnujg fgxjlli
# 20              Gkfrgjgkxg ghjndrnc
# 21                  Srgurgj fgxjlnl
# 22             Rfbhggygghrj ggkgxkg
# 23           Ejgvgdhkkx bhgrgnkgrwn
# 24                    Csgkggh lgdrt
# 25                Xigkggh rgndjvrqf
# ...

# %% [markdown]
# # Q4 Print the total number of unique sets. Drop any set if it contains extremely less data.

# %%
data['Alloted Set'].unique()
# Out:
# array([1, 3, 4, 2, 5])

# %%
dt= data['Alloted Set'].value_counts()
print(dt)
# Out:
# 1    1379
# 2     890
# 3     492
# 4     362
# 5       1
# Name: Alloted Set, dtype: int64

# %%
for i in range(0,3130):
    if(df.loc[i,"Alloted Set"]==5):
        df.drop(df.index[i])
df.tail()
# Out:
#       Sr No.       Username                  Name                  Email  \
# 3125    3126  etrjpsthjj02i  riGhubhgy Xrjfgxhjkg  etrjpsthjj02i@xyz.com
# 3126    3127     dnsmsn623v     ysNgygn Kkxhgrjdo     dnsmsn623v@xyz.com
# 3127    3128   bvstssl6860r     kcVgxggl Gkkgnjcb   bvstssl6860r@xyz.com
# 3128    3129      khkd2480w      osHxggv Drdhjgkb      khkd2480w@xyz.com
# 3129    3130  nsshrsbh_rsjv       tyGgurgbh Rgjhh  nsshrsbh_rsjv@xyz.com
#
#       Alloted Set  Total Score  Section1  Wrong Answers 1  Marks 1  Section2  \
# 3125            1           27        25               13       12        25
# 3126            1           44        25               11       14        25
# 3127            1           43        25               11       14        25
# 3128            1           49        25                6       19        25
# 3129            1           45        25               11       14        23
#
# ...

# %%
df.shape
# Out:
# (3130, 21)

# %% [markdown]
# ## Question 5

# %%
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==1):
        count=count+1
        temp=df.loc[i,'Total Score']
        marks=marks+temp
marks=(marks/count)
print('the number of students in set 1 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==2):
        count=count+1
        temp=df.loc[i,'Total Score']
        marks=marks+temp
marks=(marks/count)
print('the number of students in set 2 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==3):
        count=count+1
        temp=df.loc[i,'Total Score']
        marks=marks+temp
marks=(marks/count)
print('the number of students in set 3 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==4):
        count=count+1
        temp=df.loc[i,'Total Score']
        marks=marks+temp
marks=(marks/count)
print('the number of students in set 4 is {0} and average percentage is {1}'.format(count,marks) )
# Out:
# the number of students in set 1 is 1384 and average percentage is 38.8742774566474
# the number of students in set 2 is 890 and average percentage is 36.9314606741573
# the number of students in set 3 is 492 and average percentage is 31.695121951219512
# the number of students in set 4 is 362 and average percentage is 30.34806629834254

# %% [markdown]
# ## question 6

# %%
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==1):
        if(df.loc[i,'Total Score']>40):
            count=count+1
            temp=df.loc[i,'Total Score']
            marks=marks+temp
marks=(marks/count)
print('the number of students in set 1 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==2):
        if(df.loc[i,'Total Score']>40):
            count=count+1
            temp=df.loc[i,'Total Score']
            marks=marks+temp
marks=(marks/count)
print('the number of students in set 2 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==3):
        if(df.loc[i,'Total Score']>40):
            count=count+1
            temp=df.loc[i,'Total Score']
            marks=marks+temp
marks=(marks/count)
print('the number of students in set 3 is {0} and average percentage is {1}'.format(count,marks) )
count=0
marks=0
for i in range(3129):
    if(df.loc[i,'Alloted Set']==4):
        if(df.loc[i,'Total Score']>40):
            count=count+1
            temp=df.loc[i,'Total Score']
            marks=marks+temp
marks=(marks/count)
print('the number of students in set 4 is {0} and average percentage is {1}'.format(count,marks) )
# Out:
# the number of students in set 1 is 656 and average percentage is 47.97713414634146
# the number of students in set 2 is 348 and average percentage is 47.020114942528735
# the number of students in set 3 is 113 and average percentage is 47.15929203539823
# the number of students in set 4 is 55 and average percentage is 47.43636363636364

# %% [markdown]
# ## question 7

# %%
import matplotlib.pyplot as plt
x=df['Alloted Set'].unique()
y=df['Alloted Set'].value_counts()
y
plt.bar(x,y,color='purple',label='red',width=0.5)
plt.show()

# %% [markdown]
# ## question 8

# %%
for name,value in df.groupby('Alloted Set'):
    if name == 1:
        x=list(df['Total Score'])
    if name == 2:
        x1=list(df['Total Score'])
    if name == 3:
        x2=list(df['Total Score'])
    if name == 4:
        x3=list(df['Total Score'])
plt.subplot(2,2,1)
plt.hist(x,100,color='red',label='Set 1')
plt.subplot(2,2,2)
plt.hist(x1,70,color='blue',label='Set 2')
plt.show()
plt.subplot(2,2,1)
plt.hist(x2,50,color='green',label='Set 3')
plt.subplot(2,2,2)
plt.hist(x3,30,color='yellow',label='Set 4')
plt.show()

# %% [markdown]
# # Q9 Plot a scatter plot for section wise marks vs total marks for each section. Use subplot. Also use different colours for different range of total marks (0-40,40-60,60-100)

# %%
one=data['Marks 1']
two= data['Marks 2']
three=data['Marks 3']
four=data['Marks 4']
five=data['Marks 5']
one1=data['Section1']
two2= data['Section2']
three3=data['Section3']
four4=data['Section4']
five5=data['Section5']
plt.figure(figsize=[20,4])
plt.subplot(1,5,1)
plt.scatter(one,one1,color="r",label="red",marker="o",s=20)
plt.legend()
plt.subplot(1,5,2)
plt.scatter(two,two2,color="b",label="red",marker="o",s=20)
plt.legend()
plt.subplot(1,5,3)
plt.scatter(three,three3,color="g",label="green",marker="o",s=20)
plt.legend()
plt.subplot(1,5,4)
plt.scatter(four,four4,color="r",label="red",marker="o",s=20)
plt.subplot(1,5,5)
plt.scatter(five,five5,color="r",label="red",marker="o",s=20)

# %% [markdown]
# # Q10 BONUS QUESTION: Out of the 5 sections, 2 sections have a high correlation. Find those sections and prove by a valid plot/graph/chart/table with a proper reasoing statement. (1 point)

# %%
y=df[["Section1"]].mean()
print(y)
x=df[["Section2"]].mean()
print(x)
z=df[["Section3"]].mean()
print(z)
a=df[["Section4"]].mean()
print(a)
u=df[["Section5"]].mean()
print(u)
# Out:
# Section1    21.785304
# dtype: float64
# Section2    21.340575
# dtype: float64
# Section3    11.475032
# dtype: float64
# Section4    9.676697
# dtype: float64
# Section5    21.321383
# dtype: float64

# %%
#plt.bar(two2,five5,color="b",label="red",marker="o",s=20)
#plt.legend()
lol=data['Total Score']
plt.plot(two2,lol,color='r')
plt.show()
plt.plot(five5,lol,color='g')
plt.show()
plt.plot(one1,lol,color='r')
plt.show()
plt.plot(three3,lol,color='r')
plt.show()
plt.plot(four4,lol,color='r')
plt.show()

# %% [markdown]
# # Q 11 Print the maximum and minimum marks scored in each section. Which section has got highest maximum marks? Which section has got lowest maximum marks.

# %%
a=df[["Section1"]].min()
b=df[["Section2"]].min()
c=df[["Section3"]].min()
d=df[["Section4"]].min()
e=df[["Section5"]].min()
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# Section1    0
# dtype: int64
# Section2    0
# dtype: int64
# Section3    0.0
# dtype: float64
# Section4    0.0
# dtype: float64
# Section5    0.0
# dtype: float64

# %%
a=df[["Marks 1"]].max()
b=df[["Marks 2"]].max()
c=df[["Marks 3"]].max()
d=df[["Marks 4"]].max()
e=df[["Marks 5"]].max()
print(a)
print(b)
print(c)
print(d)
print(e)
print("Section 4 has lowest maximum marks")
print("Section 1 has highest maximum marks")
# Out:
# Marks 1    24
# dtype: int64
# Marks 2    22
# dtype: int64
# Marks 3    11.0
# dtype: float64
# Marks 4    6.0
# dtype: float64
# Marks 5    23.0
# dtype: float64
# Section 4 has lowest maximum marks
# Section 1 has highest maximum marks

# %% [markdown]
# # Q12 Print the name of toppers for each section. If there are multiple topper students in any section, print the count and names of all of them.

# %%
a=df[["Marks 1","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 1']>temp:
        temp=a.loc[i,"Marks 1"]
print(temp)
for i in range (0,3130):
    if temp==a.loc[i,"Marks 1"]:
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 24
# rnGhwrxgbh Ghrkhgrkh
# 1

# %%
a=df[["Marks 2","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 2']>temp:
        temp=a.loc[i,"Marks 2"]
print(temp)
for i in range (0,3130):
    if temp==a.loc[i,"Marks 2"]:
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 22
# ruGbhjjrrx Ygyggrnx
# 1

# %%
a=df[["Marks 3","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 3']>temp:
        temp=a.loc[i,"Marks 3"]
print(temp)
for i in range (0,3130):
    if temp==a.loc[i,"Marks 3"]:
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 11.0
# kdFrjygnkg Rggrkgrys
# qhghgzgd khgnub
# suGknglj Jgygdgrny
# 3

# %%
a=df[["Marks 4","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 4']>temp:
        temp=a.loc[i,"Marks 4"]
print(temp)
for i in range (0,3130):
    if temp==a.loc[i,"Marks 4"]:
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 6.0
# qpgnrhgl hglwgjue
# ymGhubhgy Ggwgnxyh
# cfkykgr fgwgrat
# tlYggh Jgjgwglee
# ynRjghjkrgh Ygdgvso
# nqYgnkj Kuygrjx
# yyFGRJXKGH GKFRzy
# loD GHHBHGY KHYGRad
# raGkyngxh Njwhgrrzh
# geLgxyjkgnx Lknjeq
# miRghul Jglgnfv
# ieGrjxrg Bgnrrjrrjw
# 12

# %%
a=df[["Marks 5","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 5']>temp:
        temp=a.loc[i,"Marks 5"]
print(temp)
for i in range (0,3130):
    if temp==a.loc[i,"Marks 5"]:
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 23.0
# zgGvjghrk Gghkkck
# 1

# %% [markdown]
# # Q13 Plot a stack bar plot of sectionwise scores of the topper.

# %%
import matplotlib.pyplot as plt
a="1 to 5"
data_1=df[["Marks 1","Marks 2","Marks 3",'Marks 4','Marks 5']]
plt.figure()
plt.xlabel="Section"
plt.ylabel="top score"
plt.bar(a,df['Marks 1'].max(),align="center",color="r",label="1",width=0.3)
plt.bar(a,df['Marks 2'].max(),align="center",color="y",label="2",width=0.3)
plt.bar(a,df['Marks 3'].max(),align="center",color="g",label="3",width=0.3)
plt.bar(a,df['Marks 4'].max(),align="center",color="blue",label="4",width=0.3)
plt.bar(a,df['Marks 5'].max(),align="center",color="pink",label="5",width=0.3)
plt.legend()

# %% [markdown]
# # Q 14Print the names of students in every section who have secured the maximum Correct/Total ratio. If there are multiple topper students in any section, print the count and names of all of them.

# %%
a=df[["Marks 1","Section1","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 1']>temp:
        temp=(a.loc[i,"Marks 1"])/(a.loc[i,"Section1"])
print(temp)
for i in range (0,3130):
    if temp==(a.loc[i,"Marks 1"])/(a.loc[i,"Section1"]):
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 0.56
# bwnjxjn kuygrov
# bbGHJJXKHYGR RKHXRGYfh
# nudrbggjgh fgrjdg fgrjdgyi
# ugXgrun Kjngrrua
# iwgghjl gjnglgnm
# paYglvrrn Gghkxghi
# wrghrjyg whguhgnjv
# isRgghgv Yghrghwgrjpy
# xnDjvygnghu kuygrze
# bbRkbjn ghgrygtx
# hkGdjxj Rgng Rgnglc
# obBglwjndrr Kgur Kgurxx
# yrNrhg Ghrrrtk
# zxYrjdugyjxg Bhgggwgxjbe
# iyGubhgdrrf Kgrgkes
# pmYgngg Frgygnjk Frgygnjkqs
# virjnkj kuygrjtw
# rmygnjrrx bgrgldt
# puRJXH GGGGRoe
# vxVjghwgy Jgjgwglbv
# nmGHHBHGY GKHRGBHwk
# kqGHHBHGY GJNGHwh
# mpXgnyg Kuygrjaf
# nzGbhjghrk Ghkghwg
# afRjghj FGHLgt
# fzkgljy gnggrjtw
# neGKHRGV FGNDRYqu
# hxGNKJXG BHGXXGWHGRYGto
# hkGbhjjrrx Gbhjjrrxvk
# xaGYGN KHYGRhf
# ojGRJJRR BJGWGGlf
# glGhjvgy Drwgnggnpu
# xhGgfxgdrrf Yukhrrjrrrk
# ebFRGGHGN GRJVGGXGVGse
# ovGgurgv Ghgrygmo
# omGHGLGKG KRRRxa
# ffGHHBHGY ZGGGDRyy
# xeGuyrdhg Fhgdnjgvx
# gvGhubhgy Fglkgrgs
# nukjrxj bhkgglrnb
# wvGkghgy Wgdrkgruj
# icNjxjgh Fgxjlyj
# xmBglkrjghng ngndkgkgrnx
# feGdjxj Fgggrrkr
# zgKgvjrgj xgndrlxr
# znGwgfnjl Rgggyvq
# ...

# %%
a=df[["Marks 2","Section2","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 2']>temp:
        temp=(a.loc[i,"Marks 2"])/(a.loc[i,"Section2"])
print(temp)
for i in range (0,3130):
    if temp==(a.loc[i,"Marks 2"])/(a.loc[i,"Section2"]):
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 0.43478260869565216
# uygyrdkjghgx gljvq
# maNJghjggndhg Fgxjlcd
# ylGubhkjjx DggYkhgnxglv
# tyGgurgbh Rgjhh
# 4
# c:\users\priya\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   if __name__ == '__main__':

# %%
a=df[["Marks 3","Section3","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 3']>temp:
        temp=(a.loc[i,"Marks 3"])/(a.loc[i,"Section3"])
print(temp)
for i in range (0,3130):
    if temp==(a.loc[i,"Marks 3"])/(a.loc[i,"Section3"]):
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 0.4166666666666667
# shBjghwgjrrx Ygndglqm
# afRjghj FGHLgt
# vlVjygl Kughwghgzk
# ldGbhjjrrx Fjdgrqq
# lqXHGHGR Jhggx
# cgKgnwhgn Kuygrjqn
# mhVjkgg Vjghwgkgrygty
# ltGqjb Ghgjkhoq
# tyGgurgbh Rgjhh
# 9
# c:\users\priya\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
a=df[["Marks 4","Section4","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 4']>temp:
        temp=(a.loc[i,"Marks 4"])/(a.loc[i,"Section4"])
print(temp)
for i in range (0,3130):
    if temp==(a.loc[i,"Marks 4"])/(a.loc[i,"Section4"]):
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 0.3
# hfkgyrgn gljkhgnlz
# hrHJYGNGHH DKBHGLzg
# kkbhufrndrg whguhgniy
# ntGjghwgryg Ggbglrkc
# gkFrgjgkxg ghjndrnc
# xiGkggh Rgndjvrqf
# icGykl Ggrgvgdrmh
# jcGhwrxg Fgnjwgnjbo
# coygnjghg djndrew
# egNjkhjl Khkwhgrrtr
# qlKNKGR KHWHRKGRyb
# ilXrjgghrj Ghgxggrgf
# uiRgvjng Ggnggknkgryr
# gyFrgnjxg Jngglrqv
# izGhjvgnj Fgwgrtm
# ghFrgngv Gndhglkgrdy
# nfRkhjx Dufgdrkj
# cvvgjbhgv kkrrdn
# skvjghgl kkljlr
# thGkghgy Whgvgnou
# kjYuvrgj Jgdhgvnm
# cfvjghgl kurlrmg
# awNJLRGH DHHYGLbt
# ltVgjghngvj Gglunkhrny
# rfghubhgngj wgvgrrme
# ffFkurnjyg Kkrrvw
# pwWggjy Yggduyow
# yoVjvrk Gurgvot
# jugkurgbh dgkgrrek
# zrGKHRGBH HHLWGNde
# hrGGJJD YKYJNoz
# glRGGJKG YGNDLJKpv
# bjgrujrrx ghjngrkk
# lzKnkgr Kulkgrrs
# jxGhubhgy Kgyblrry
# deggyruddhj gurygwgnghjnn
# eyKKYGL HGNDRhd
# jlvjghgl whgvgnnq
# tgFrgnjxg Fgxjljc
# lnGGHRGBH BHGLKGRhe
# kgJGYDRRF GDYHXHRiw
# sygkghgxg kgllkljzk
# voGHHBHGY GHRYGWGNGHJxt
# whggurgbh gglunkhraw
# hlGKGHGY GGVGDRkv
# vxGNJKRX YHLJKkb
# csFrjxgy ygjggknkgrli
# ...

# %%
a=df[["Marks 5","Section5","Name"]]
temp=0
c=0
for i in range (0,3130):
    if a.loc[i,'Marks 5']>temp:
        temp=(a.loc[i,"Marks 5"])/(a.loc[i,"Section5"])
print(temp)
for i in range (0,3130):
    if temp==(a.loc[i,"Marks 5"])/(a.loc[i,"Section5"]):
        c+=1
        print(a.loc[i,"Name"])
print(c)
# Out:
# 0.52
# hfkgyrgn gljkhgnlz
# hrHJYGNGHH DKBHGLzg
# nhRGGHH WHGHDHGRYde
# rvGygndrrf Kgurmi
# mbnjghxhg bgbbgrnl
# tjJggkjrgx Gjnghrk
# ikGyjx Fgxhgnjgyd
# meYgnjgh Kuygrag
# beGygnfrrrx Fgrygrsy
# tiXgrun Furjee
# paYukrgh Ygdgvfs
# oqHgrkjrgx Bjrdjpj
# jtRjwhg Whguhgnxq
# suGHGHJL FRGGGDjx
# woGhjvgnj xhgkurgv
# ksRghul Dhjygnim
# qgGurfrrrx gjnghex
# xoJggfrrrx kgurmb
# zcGrghFrrrx KGur KGuryt
# atHjwgrglr Gkurgv Djljfnh
# waRjghgv Ghgrygnp
# mlGghuxkgh Kuygrja
# pmYgngg Frgygnjk Frgygnjkqs
# dpFrgkhgr Gggrwglzk
# vxVjghwgy Jgjgwglbv
# rmGghjgh Gghjghev
# nmGHHBHGY GKHRGBHwk
# pwGkurgyjxg Drbngxhvt
# jbXHGHGR BGHGKGRkk
# jwGrkk Bhgxxgwhgrygto
# jyNJXJN KHYGRzl
# cmghgkxj gjnghxt
# ggGNJRHDDHG KGRYGKGRje
# ewRgughgn kuygrad
# hvGhjghgnghu Ygdgvro
# evGnwrghg Gghgdv
# nsFrrrxgy Gngnd Gngndus
# zpNjkjxg Nufurqs
# akGNJKRX GGHRGVwk
# kcGkhjnj grnbz
# hzFrjygnkg Ghkghba
# rbRghul rgjrq
# zeGvgnxjkg Gjnghde
# mgGrrrb Glgyjo
# ysgkgnkghyg ykhgfgxrgkc
# mdGNGNYG Gngnygzm
# fbGughjl Kuygrkl
# ...

# %% [markdown]
# # Q15 Find out if there is any student who is topper in both above questions (section wise). Such students will be called scholars. Prints the names of all scholars.

# %%
#question 15
df['topper1']=x
x=df['Marks 1']/df['Total Score']
df['topper2']=x1
x1=df['Marks 2']/df['Total Score']
df['topper3']=x2
x2=df['Marks 3']/df['Total Score']
df['topper4']=x3
x3=df['Marks 4']/df['Total Score']
b1=df['topper1'].max()
b2=df['topper2'].max()
b3=df['topper3'].max()
b4=df['topper4'].max()
a1=df['Marks 1'].max()
a2=df['Marks 2'].max()
a3=df['Marks 3'].max()
a4=df['Marks 4'].max()
print('the Scholars are: \n')
for i in range(3129):
    if(df.loc[i,'Marks 1']==a1):
        if(df.loc[i,'topper1']==b1):
            print(df.loc[i])
print('*********')
for i in range(3129):
    if(df.loc[i,'Marks 2']==a2):
        if(df.loc[i,'topper2']==b2):
            print(df.loc[i])
print('*********')
for i in range(3129):
    if(df.loc[i,'Marks 3']==a3):
        if(df.loc[i,'topper3']==b3):
            print(df.loc[i])
print('*********')
for i in range(3129):
    if(df.loc[i,'Marks 4']==a4):
        if(df.loc[i,'topper4']==b4):
            print(df.loc[i])
# Out:
# the Scholars are:
#
# *********
# *********
# *********

# %% [markdown]
# # Q 16 Print the names of students who scored zero.

# %%
zero=df[["Total Score","Name"]]
for i in range (0,3130):
    if zero.loc[i,'Total Score']==0:
        print(zero.loc[i,'Name'])
# Out:
# ppggwhjn ykhjxrty
# fcgnurgdhg kuygrjnc

# %% [markdown]
# # Q17Find the count of all students whose Incorrect/Correct Ratio in all sections is more than 1.

# %%
df['topper1']=x
x=df['Marks 1']/df['Wrong Answers 1']
df['topper2']=x1
x1=df['Marks 2']/df['Wrong Answers 2']
df['topper3']=x2
x2=df['Marks 3']/df['Wrong Answers 3']
df['topper4']=x3
x3=df['Marks 4']/df['Wrong Answers 4']
for i in range(3129):
    if(df.loc[i,'topper1']>1):
        print(df.loc[i])
        print('*********')
    if(df.loc[i,'topper2']>1):
        print(df.loc[i])
        print('*********')
    if(df.loc[i,'topper3']>1):
        print(df.loc[i])
        print('*********')
    if(df.loc[i,'topper4']>1):
        print(df.loc[i])
# Out:
# Sr No.                               1
# Username                   usmjtsrkrsl
# Name                  jalkvjgh grkrgtt
# Email              usmjtsrkrsl@xyz.com
# Alloted Set                          1
# Total Score                         34
# Section1                            25
# Wrong Answers 1                     12
# Marks 1                             13
# Section2                            25
# Wrong Answers 2                     20
# Marks 2                              5
# Section3                            15
# Wrong Answers 3                     11
# Marks 3                              4
# Section4                            10
# Wrong Answers 4                      9
# Marks 4                              1
# Section5                            25
# Wrong Answers 5                     14
# Marks 5                             11
# topper1                        1.08333
# topper2                           0.25
# topper3                       0.363636
# ...

# %% [markdown]
# # NO scholars so can't do Q18
